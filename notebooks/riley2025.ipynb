# %%
from ocr import catalog

# %%
catalog
# Out:
#                                         📊 OCR Dataset Catalog (9 datasets)
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name                 ┃ Description                 ┃ Format ┃ Version       ┃ Storage Location                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 2011-climate-run     │ USFS 2011 Climate Run       │ zarr   │ v1            │ s3://carbonplan-ocr/input/fire-ri │
# │                      │                             │        │               │ sk/tensor/USFS/2011ClimateRun_Ice │
# │                      │                             │        │               │ chunk                             │
# ├──────────────────────┼─────────────────────────────┼────────┼───────────────┼───────────────────────────────────┤
# ...

# %%
riley = {}
riley['2011'] = catalog.get_dataset('2011-climate-run').to_xarray()
riley['2047'] = catalog.get_dataset('2047-climate-run').to_xarray()
riley
# Out:
# {'2011': <xarray.Dataset> Size: 11GB
#  Dimensions:      (y: 11062, x: 17237)
#  Coordinates:
#    * x            (x) float64 138kB -2.356e+06 -2.356e+06 ... 2.297e+06 2.298e+06
#    * y            (y) float64 88kB 3.237e+06 3.237e+06 ... 2.511e+05 2.508e+05
#  Data variables:
#      BP           (y, x) float64 2GB dask.array<chunksize=(6000, 4500), meta=np.ndarray>
#      FLP3         (y, x) float64 2GB dask.array<chunksize=(6000, 4500), meta=np.ndarray>
#      FLP2         (y, x) float64 2GB dask.array<chunksize=(6000, 4500), meta=np.ndarray>
#      FLP1         (y, x) float64 2GB dask.array<chunksize=(6000, 4500), meta=np.ndarray>
#      FLP4         (y, x) float64 2GB dask.array<chunksize=(6000, 4500), meta=np.ndarray>
#      FLP6         (y, x) float64 2GB dask.array<chunksize=(6000, 4500), meta=np.ndarray>
#      FLP5         (y, x) float64 2GB dask.array<chunksize=(6000, 4500), meta=np.ndarray>
#      spatial_ref  int64 8B ...,
#  '2047': <xarray.Dataset> Size: 11GB
# ...

# %%
dillon = catalog.get_dataset('wildfire-communities').to_xarray()
dillon = dillon.drop_vars(['band', 'spatial_ref']).squeeze()
dillon
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fad1961a490>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fad194cd430>, 97.215767401)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fad19836fd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fad19618cd0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fad194cd1f0>, 97.23038319)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fad19618910>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fad197f25d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fad194ccfb0>, 97.268478363)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fad197f2210>
# <xarray.Dataset> Size: 11GB
# Dimensions:  (y: 11283, x: 17372)
# Coordinates:
# ...

# %%
# Plot 270m historical and future risk

# %%
# Plot change signal across CONUS

# %%
# Compare Riley 2025 w Dillon 2023 and Dye 2024
