# %%
from ocr import catalog

# %%
catalog
# Out:
#                                         📊 OCR Dataset Catalog (8 datasets)
# ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Name                 ┃ Description                 ┃ Format ┃ Version       ┃ Storage Location                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 2011-climate-run     │ USFS 2011 Climate Run       │ zarr   │ v1            │ s3://carbonplan-ocr/input/fire-ri │
# │                      │                             │        │               │ sk/tensor/USFS/2011ClimateRun_Ice │
# │                      │                             │        │               │ chunk                             │
# ├──────────────────────┼─────────────────────────────┼────────┼───────────────┼───────────────────────────────────┤
# ...

# %%
riley = {}
riley['2011'] = catalog.get_dataset('2011-climate-run').to_xarray(is_icechunk=True)
riley['2047'] = catalog.get_dataset('2047-climate-run').to_xarray(is_icechunk=True)
riley
# Out:
# {'2011': <xarray.Dataset> Size: 11GB
#  Dimensions:      (y: 11062, x: 17237)
#  Coordinates:
#    * y            (y) float64 88kB 3.237e+06 3.237e+06 ... 2.511e+05 2.508e+05
#    * x            (x) float64 138kB -2.356e+06 -2.356e+06 ... 2.297e+06 2.298e+06
#  Data variables:
#      BP           (y, x) float64 2GB ...
#      FLP1         (y, x) float64 2GB ...
#      FLP3         (y, x) float64 2GB ...
#      FLP2         (y, x) float64 2GB ...
#      FLP5         (y, x) float64 2GB ...
#      spatial_ref  int64 8B ...
#      FLP4         (y, x) float64 2GB ...
#      FLP6         (y, x) float64 2GB ...,
#  '2047': <xarray.Dataset> Size: 11GB
#  Dimensions:      (y: 11166, x: 17237)
#  Coordinates:
#    * y            (y) float64 89kB 3.265e+06 3.265e+06 ... 2.511e+05 2.508e+05
#    * x            (x) float64 138kB -2.356e+06 -2.356e+06 ... 2.297e+06 2.298e+06
#  Data variables:
#      FLP1         (y, x) float64 2GB ...
#      FLP3         (y, x) float64 2GB ...
# ...

# %%
dillon = catalog.get_dataset('wildfire-communities').to_xarray(is_icechunk=False)
dillon = dillon.drop_vars(['band', 'spatial_ref']).squeeze()
dillon
# Out:
# <xarray.Dataset> Size: 11GB
# Dimensions:  (y: 11283, x: 17372)
# Coordinates:
#   * x        (x) float64 139kB -2.363e+06 -2.362e+06 ... 2.327e+06 2.328e+06
#   * y        (y) float64 90kB 3.268e+06 3.267e+06 ... 2.217e+05 2.214e+05
# Data variables:
#     BP       (y, x) float64 2GB ...
#     FLP1     (y, x) float64 2GB ...
#     FLP2     (y, x) float64 2GB ...
#     FLP3     (y, x) float64 2GB ...
#     FLP4     (y, x) float64 2GB ...
#     FLP5     (y, x) float64 2GB ...
#     FLP6     (y, x) float64 2GB ...

# %%
# Plot 270m historical and future risk

# %%
# Plot change signal across CONUS

# %%
# Compare Riley 2025 w Dillon 2023 and Dye 2024
